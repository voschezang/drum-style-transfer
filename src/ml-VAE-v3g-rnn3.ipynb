# %%
from __future__ import division

import collections
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

## NN libs
import keras
from keras import backend as K
from keras import regularizers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
from keras.layers import *
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.callbacks import TensorBoard
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import config
import os, numpy as np, pandas, sklearn, scipy.signal as signal
import mido
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# local libs
import config, models, setup
import midi
from midi import generators as g
from utils import io, models_io, utils, plot

# %%
context = setup.init()
# Out:
#  Context :: namedtuple(
# [ max_t = float
# , dt = float
# , n_timestesp = int
# , note_length = int
# , bpm = float
# , tempo = float
# , ticks_per_beat = int
# ]
#
# Setting up params
#
# max min f 10.0 0.5
#  >> Context(max_t=2.0, dt=0.05, n_timesteps=40, note_length=0.03, bpm=120.0, tempo=500000, ticks_per_beat=480)
#  sample length:  40.000000
#  max_f: 10.000000, min_f: 0.500000

# %%
n = 10 * 1
dim4 = True
multiTrack = True
reduce_dims = midi.ReduceDimsOptions.MIDIFILE # GLOBAL
dn = 'drum_midi/'
x_train, labels = setup.import_data(context, n, dim4=dim4, reduce_dims=reduce_dims, dirname=dn, multiTrack=multiTrack, r=True)
# Out:
# Importing midi-data
#
# Encoding midi-data
#  10
# > -> multi-track = True MidiFile
#  [INFO] :
#  |  True

# %%
# n = 1000
# min_f = 0
# max_f = 3
# x_train, params = g.gen_data_complex(context, n, max_f=max_f, min_f=min_f,
#     n_polyrythms=1,
#     n_channels=3,
#     d_phase=True,
#     return_params=True,
#     dim4=dim4,
#     multiTrack=multiTrack)

# %%
x_train.shape
# Out:
# (10, 40, 10, 1)

# %%
m = int(x_train.shape[0] * 0.9)
x_train.shape, m
# Out:
# ((10, 40, 10, 1), 9)

# %%
x_test = x_train[m:]
x_train = x_train[:m]

# %%
plot.single(x_train[0, :50,:,0])
plot.single(x_train[1, :50,:,0])
# plot.single(x_train[2, :50,:,0])
labels[0:4]
# Out:
# m (40, 10)
# m (40, 10)
# ["../datasets/drum_midi//50´s Drummer MIDI Files/01 Rock'n'Roll/01 Dancin Rick 166BPM/01 8th Hat.mid",
#  "../datasets/drum_midi//50´s Drummer MIDI Files/01 Rock'n'Roll/01 Dancin Rick 166BPM/02 8th Ride.mid",
#  "../datasets/drum_midi//50´s Drummer MIDI Files/01 Rock'n'Roll/01 Dancin Rick 166BPM/03 16th Snare.mid",
#  "../datasets/drum_midi//50´s Drummer MIDI Files/01 Rock'n'Roll/01 Dancin Rick 166BPM/04 8th Ride.mid"]

# %%
input_shape = x_train[0].shape
timesteps = input_shape[0]
notes = input_shape[1]
input_shape
# Out:
# (40, 10, 1)

# %%
latent_dim = 2
intermediate_dim = 128
epsilon_std = 1.0

# %%
def encoder(input_shape, dropout=0.1):
    encoder_input = Input(shape=input_shape)
    nodes = np.prod(input_shape)

    # Convolution
    h = encoder_input
    h = Reshape(input_shape[:-1])(h)
    h = Conv1D(32, kernel_size=2, strides=1, activation='relu', padding='valid')(h)
    h = Conv1D(64, kernel_size=2, strides=2, activation='relu', padding='valid')(h)
    h = Conv1D(128, kernel_size=2, strides=1, activation='relu', padding='valid')(h)
#     h = Dropout(dropout)(h) # uncomment when using larger batches

    # RNN
    shape = K.int_shape(h)[1:]
    h = SimpleRNN(256)(h)

    # Dense layers
#     h = Flatten()(h)
#     h = Dropout(dropout)(h) # uncomment when using larger batches
    
    h = Dense(intermediate_dim*2, activation='relu')(h)
    h = Dense(intermediate_dim, activation='relu')(h)
   
    # Z Mean, Variance
    z_mean = Dense(latent_dim, name='z_mean')(h) # , activation='relu'
    z_log_var = Dense(latent_dim, name='z_log_var')(h) # , activation='relu'
        
    encoder_output = [z_mean, z_log_var]
    encoder_model = Model(encoder_input, encoder_output, name='encoder_model-')
    return encoder_model, encoder_input, z_mean, z_log_var

# %%
encoder_model, encoder_input, z_mean, z_log_var = encoder(input_shape)
encoder_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 40, 10, 1)    0
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 40, 10)       0           input_7[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 39, 32)       672         reshape_18[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 19, 64)       4160        conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 18, 128)      16512       conv1d_17[0][0]
# __________________________________________________________________________________________________
# simple_rnn_12 (SimpleRNN)       (None, 256)          98560       conv1d_18[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 256)          65792       simple_rnn_12[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 128)          32896       dense_65[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            258         dense_66[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            258         dense_66[0][0]
# ==================================================================================================
# Total params: 219,108
# Trainable params: 219,108
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
sample_ = lambda args: models.sample(args, z_mean, z_log_var, latent_dim, epsilon_std)

# %%
# z = Lambda(sampling)([z_mean, z_log_var])
z_input = encoder_model(encoder_input)
z_output = Lambda(sample_)(z_input)
# z_output = Lambda(sampl_, output_shape=(latent_dim,))(encoder_input)

# %%
def list_decoders(output_shape, p='same'):
    # decoder_input = z_output
    # h = decoder_input
    # :output_shape = (timesteps, channels, channels) || (batches, filters, timesteps, channels)
    # keras offers just Conv2DTranspose and not Conv1DTranspose
    # - use 2D images during upsampling :: (timesteps, notes, channels) => (timesteps, notes, filters)
    # - use 1D images to optimize reconstruction :: (timesteps, filters) => (timesteps, notes)
    
    # image_data_format = 'channels_last'
    # goal shape: (timesteps, notes, channels)
    # start with the 'reverse': lots of small imgs => few large img
    
    timesteps, notes, channels = output_shape
    time_ = int(timesteps/10)
    notes_ = notes * 10
    intermediate_dim = time_ * notes_ * channels
    # at the start of upsampling, the image-structure does not yet have to correspond to the goal structure 
    # ?TODO use y*y*y starting dims, may conv, and only then correct the structure (?)
    output_shape = (timesteps, notes, channels)
    nodes = np.prod(output_shape)
    
    decoders = []
    decoders += [ Dense(256, activation='relu') ]
    decoders += [ Dense(256, activation='relu') ]
        
    # RNN
    dim1, dim2 = 8, 32 # 8*32=256
    # decoders += [ Reshape((dim1, dim2)) ]
    # decoders += [ SimpleRNN(128, return_sequences='True') ]
    
    branch1 = []
    branch1 += [ Dense(dim2, activation='relu') ] # constant value, a note-column for every timestep
    branch1 += [ RepeatVector(dim1) ] 
    
    branch2 = []
    branch2 += [ Dense(dim1 * dim2, activation='relu') ]
    branch2 += [ Reshape([dim1, dim2]) ]
    
    branch1_ = lambda layer: utils.composition(branch1, layer)
    branch2_ = lambda layer: utils.composition(branch2, layer)
    decoders += [ lambda layer: Add()([branch1_(layer), branch2_(layer)]) ]
    
    decoders += [ SimpleRNN(256, return_sequences='True') ]
    # rnn = SimpleRNN(dims, activation='sawDescending', return_sequences=True)
    
    #TODO     LocallyConnected2D, TimeDistributed(transposed(x))
    # TODO 2nd RNN to generate the 'repeating' state (aka decay matrix)
    decoders += [ Flatten() ]
    decoders += [ Dense(nodes, activation='relu') ]
#     decoders += [ Dense(nodes, activation='relu') ]
#     decoders += [ Dropout(0.05) ]

#     # Convolution
#     # Note that the kernel windows do not yet correspond to 'temporal' features, but rather to just spatial features
#     k = (2,1) # (2,1) :: (timesteps, notes)
#     s = (3,1)

#     decoders += [ Reshape((time_, notes_, channels)) ]
#     decoders += [ Conv2DTranspose(128, kernel_size=2, strides=3, activation='relu', padding=p) ]
    
#     # 'end' of upsampling
#     decoders += [ Conv2D(32, kernel_size=(1,2), strides=(1,3), activation='relu', padding=p) ]

    output_shape = (timesteps, notes, channels)
    
# #     decoders += [ Flatten()]
#     decoders += [ Dense(np.prod(output_shape), activation='relu')]
    decoders += [ Dense(np.prod(output_shape), activation='sigmoid')]
    decoders += [ Reshape(output_shape)]
    return decoders

# %%
decoders = list_decoders(input_shape)

# %%
decoded = utils.composition(decoders, z_output, verbose=False)

# %%
# instantiate VAE model
vae_input = encoder_input
vae_output = decoded
vae = Model(vae_input, vae_output)
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 40, 10, 1)    0
# __________________________________________________________________________________________________
# encoder_model- (Model)          [(None, 2), (None, 2 219108      input_7[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 2)            0           encoder_model-[1][0]
#                                                                  encoder_model-[1][1]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 256)          768         lambda_5[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 256)          65792       dense_74[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 32)           8224        dense_75[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 256)          65792       dense_75[0][0]
# __________________________________________________________________________________________________
# repeat_vector_11 (RepeatVector) (None, 8, 32)        0           dense_76[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 8, 32)        0           dense_77[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 8, 32)        0           repeat_vector_11[0][0]
#                                                                  reshape_21[0][0]
# __________________________________________________________________________________________________
# simple_rnn_14 (SimpleRNN)       (None, 8, 256)       73984       add_9[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 2048)         0           simple_rnn_14[0][0]
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 400)          819600      flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 400)          160400      dense_78[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 40, 10, 1)    0           dense_79[0][0]
# ==================================================================================================
# Total params: 1,413,668
# Trainable params: 1,413,668
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compute VAE loss
def vae_loss(beta=1.):
    # y_true, y_pred, z_mean, z_log_var, timesteps=150, notes=3, beta=1.
    xent_loss = timesteps * notes * keras.metrics.binary_crossentropy(K.flatten(vae_input), K.flatten(vae_output))
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    vae_loss = K.mean(xent_loss + beta * kl_loss)
    return vae_loss

vae_loss = vae_loss(beta=1)
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')
# vae.compile(optimizer=optimizer, loss=loss, metrics=metrics)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:11: UserWarning: Output "reshape_22" missing from loss dictionary. We assume this was done on purpose, and we will not be expecting any data to be passed to "reshape_22" during training.
#   # This is added back by InteractiveShellApp.init_path()

# %%
batch_size = 250
epochs = 1000
params = {'batch_size': batch_size, 'return_y': False}

# %%
phase_mod = 0.01
whitening = False

# %%
m = 5
useDataGenerator = False
useDataGenerator = True

x = x_train
x = np.concatenate([x_train[:m] for _ in range(1000)])

print('batch_size =', batch_size)
if useDataGenerator:
    datagen = models.ImageDataGenerator(x_train, batch_size, phase_mod, whitening)
    history = collections.defaultdict(list)
    n_batches = datagen.__len__()
    for e in range(epochs):
        print('\n[Epoch %i/%i] >>>>>>>>>' % (e, epochs))
        for batch_i, (x_batch, y_batch) in enumerate(datagen.flow(x[:m], x[:m], batch_size)):
            print(' Batch %i/%i' % (batch_i,n_batches))
            x_ = x_batch
            # x_ = datagen.shuffle_3rd_dim(x_)
            x_ = datagen.shuffle_3rd_dim_soft(x_, mutation_rate=0.5, scale=0.1, verbose=0)
            h = vae.fit(x_, validation_data=(x_test, None), verbose=0)
            for k,v in h.history.items(): 
                print(' \\_%s' % k, [round(v_,) for v_ in v])
                history[k].append(v)
            if batch_i >= n_batches:
                break
else:
    h = vae.fit(x[:m], epochs=epochs, validation_data=(x_test, None))
    history = h.history
# Out:
# batch_size = 250
#
# [Epoch 0/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [267.0]
#  \_loss [278.0]
#
# [Epoch 1/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [2414.0]
#  \_loss [201.0]
#
# [Epoch 2/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [74.0]
#  \_loss [2594.0]
#
# [Epoch 3/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [64.0]
#  \_loss [92.0]
#
# [Epoch 4/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [86.0]
#  \_loss [109.0]
#
# [Epoch 5/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [63.0]
#  \_loss [94.0]
#
# [Epoch 6/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [88.0]
#
# [Epoch 7/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [90.0]
#
# [Epoch 8/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [84.0]
#
# [Epoch 9/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [82.0]
#
# [Epoch 10/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 11/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [78.0]
#
# [Epoch 12/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [73.0]
#
# [Epoch 13/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [61.0]
#  \_loss [80.0]
#
# [Epoch 14/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 15/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 16/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [78.0]
#
# [Epoch 17/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [75.0]
#
# [Epoch 18/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [80.0]
#
# [Epoch 19/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 20/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [74.0]
#
# [Epoch 21/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [76.0]
#
# [Epoch 22/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [47.0]
#  \_loss [77.0]
#
# [Epoch 23/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [76.0]
#
# [Epoch 24/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 25/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 26/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [75.0]
#
# [Epoch 27/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [75.0]
#
# [Epoch 28/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 29/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 30/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 31/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [75.0]
#
# [Epoch 32/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 33/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [86.0]
#
# [Epoch 34/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [84.0]
#
# [Epoch 35/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [74.0]
#
# [Epoch 36/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [79.0]
#
# [Epoch 37/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 38/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [76.0]
#
# [Epoch 39/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [79.0]
#
# [Epoch 40/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [79.0]
#
# [Epoch 41/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [79.0]
#
# [Epoch 42/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 43/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 44/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 45/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 46/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [81.0]
#
# [Epoch 47/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [78.0]
#
# [Epoch 48/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [80.0]
#
# [Epoch 49/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 50/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [84.0]
#
# [Epoch 51/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [79.0]
#
# [Epoch 52/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [76.0]
#
# [Epoch 53/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [72.0]
#
# [Epoch 54/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [63.0]
#  \_loss [69.0]
#
# [Epoch 55/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [75.0]
#
# [Epoch 56/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 57/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 58/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 59/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [75.0]
#
# [Epoch 60/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [71.0]
#
# [Epoch 61/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [78.0]
#
# [Epoch 62/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 63/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 64/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 65/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [75.0]
#
# [Epoch 66/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 67/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 68/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 69/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 70/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 71/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [83.0]
#
# [Epoch 72/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [76.0]
#
# [Epoch 73/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [74.0]
#
# [Epoch 74/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [85.0]
#
# [Epoch 75/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [74.0]
#
# [Epoch 76/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [80.0]
#
# [Epoch 77/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [71.0]
#
# [Epoch 78/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [81.0]
#
# [Epoch 79/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [81.0]
#
# [Epoch 80/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [71.0]
#  \_loss [84.0]
#
# [Epoch 81/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [110.0]
#  \_loss [90.0]
#
# [Epoch 82/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [161.0]
#
# [Epoch 83/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [84.0]
#
# [Epoch 84/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 85/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 86/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [76.0]
#
# [Epoch 87/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 88/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 89/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 90/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 91/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 92/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [69.0]
#
# [Epoch 93/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 94/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 95/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [69.0]
#
# [Epoch 96/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [66.0]
#
# [Epoch 97/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [70.0]
#
# [Epoch 98/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [69.0]
#
# [Epoch 99/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 100/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 101/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 102/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 103/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 104/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 105/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 106/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [81.0]
#
# [Epoch 107/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [73.0]
#
# [Epoch 108/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 109/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 110/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 111/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 112/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 113/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [60.0]
#  \_loss [83.0]
#
# [Epoch 114/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 115/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [80.0]
#
# [Epoch 116/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 117/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 118/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 119/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [69.0]
#
# [Epoch 120/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 121/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [70.0]
#
# [Epoch 122/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [76.0]
#
# [Epoch 123/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [68.0]
#
# [Epoch 124/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 125/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 126/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 127/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [80.0]
#
# [Epoch 128/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [72.0]
#
# [Epoch 129/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [72.0]
#
# [Epoch 130/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [74.0]
#
# [Epoch 131/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [73.0]
#
# [Epoch 132/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 133/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [79.0]
#
# [Epoch 134/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [77.0]
#
# [Epoch 135/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 136/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [72.0]
#
# [Epoch 137/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 138/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 139/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 140/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 141/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [74.0]
#
# [Epoch 142/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 143/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 144/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 145/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [46.0]
#  \_loss [72.0]
#
# [Epoch 146/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 147/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 148/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 149/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 150/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 151/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 152/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [77.0]
#
# [Epoch 153/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 154/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 155/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 156/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 157/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [77.0]
#
# [Epoch 158/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [79.0]
#
# [Epoch 159/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [80.0]
#
# [Epoch 160/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 161/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [72.0]
#
# [Epoch 162/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [75.0]
#
# [Epoch 163/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 164/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 165/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [61.0]
#  \_loss [82.0]
#
# [Epoch 166/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [78.0]
#
# [Epoch 167/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [72.0]
#
# [Epoch 168/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 169/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [72.0]
#
# [Epoch 170/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [69.0]
#
# [Epoch 171/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [75.0]
#
# [Epoch 172/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 173/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 174/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [72.0]
#
# [Epoch 175/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [77.0]
#
# [Epoch 176/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 177/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [84.0]
#
# [Epoch 178/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [46.0]
#  \_loss [74.0]
#
# [Epoch 179/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 180/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 181/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 182/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 183/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 184/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 185/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 186/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 187/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 188/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 189/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [74.0]
#
# [Epoch 190/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 191/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [69.0]
#
# [Epoch 192/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 193/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [73.0]
#
# [Epoch 194/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 195/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [69.0]
#
# [Epoch 196/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [67.0]
#
# [Epoch 197/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [72.0]
#
# [Epoch 198/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 199/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [81.0]
#
# [Epoch 200/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 201/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [79.0]
#
# [Epoch 202/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 203/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 204/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 205/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 206/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 207/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 208/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 209/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 210/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [70.0]
#
# [Epoch 211/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 212/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 213/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 214/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 215/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 216/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [72.0]
#
# [Epoch 217/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 218/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [105.0]
#  \_loss [70.0]
#
# [Epoch 219/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [155.0]
#
# [Epoch 220/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [86.0]
#
# [Epoch 221/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 222/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [81.0]
#
# [Epoch 223/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 224/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 225/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 226/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 227/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [77.0]
#
# [Epoch 228/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 229/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 230/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 231/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 232/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 233/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 234/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 235/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 236/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 237/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [81.0]
#
# [Epoch 238/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [79.0]
#
# [Epoch 239/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 240/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 241/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 242/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 243/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 244/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [80.0]
#
# [Epoch 245/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 246/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 247/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 248/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 249/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 250/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 251/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 252/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 253/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [68.0]
#
# [Epoch 254/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 255/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 256/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 257/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 258/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 259/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 260/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 261/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 262/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 263/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 264/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 265/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 266/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [67.0]
#
# [Epoch 267/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 268/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 269/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 270/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [68.0]
#
# [Epoch 271/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 272/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 273/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [83.0]
#
# [Epoch 274/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 275/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [74.0]
#
# [Epoch 276/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [76.0]
#
# [Epoch 277/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 278/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 279/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 280/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 281/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 282/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 283/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 284/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 285/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 286/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 287/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [75.0]
#
# [Epoch 288/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 289/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [80.0]
#
# [Epoch 290/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 291/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [59.0]
#  \_loss [73.0]
#
# [Epoch 292/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 293/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [84.0]
#
# [Epoch 294/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 295/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 296/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 297/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 298/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 299/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 300/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [70.0]
#
# [Epoch 301/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 302/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 303/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [68.0]
#
# [Epoch 304/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 305/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 306/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [81.0]
#
# [Epoch 307/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 308/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [79.0]
#
# [Epoch 309/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 310/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 311/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 312/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 313/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 314/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [69.0]
#
# [Epoch 315/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 316/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [68.0]
#
# [Epoch 317/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [76.0]
#
# [Epoch 318/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 319/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [75.0]
#
# [Epoch 320/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [69.0]
#
# [Epoch 321/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [77.0]
#
# [Epoch 322/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 323/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 324/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 325/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 326/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 327/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 328/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 329/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 330/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 331/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 332/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [74.0]
#
# [Epoch 333/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 334/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [74.0]
#
# [Epoch 335/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 336/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 337/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 338/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 339/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [76.0]
#
# [Epoch 340/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [80.0]
#
# [Epoch 341/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 342/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 343/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [78.0]
#
# [Epoch 344/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [77.0]
#
# [Epoch 345/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 346/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 347/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 348/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 349/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 350/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [80.0]
#
# [Epoch 351/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 352/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 353/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 354/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 355/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 356/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 357/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 358/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [79.0]
#
# [Epoch 359/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 360/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 361/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 362/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 363/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 364/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 365/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 366/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [66.0]
#
# [Epoch 367/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [80.0]
#
# [Epoch 368/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 369/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [79.0]
#
# [Epoch 370/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 371/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [64.0]
#
# [Epoch 372/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 373/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 374/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 375/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 376/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 377/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 378/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [79.0]
#
# [Epoch 379/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 380/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [67.0]
#
# [Epoch 381/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 382/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 383/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 384/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 385/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [80.0]
#
# [Epoch 386/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [77.0]
#
# [Epoch 387/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 388/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 389/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 390/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 391/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 392/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [79.0]
#
# [Epoch 393/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [76.0]
#
# [Epoch 394/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 395/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 396/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 397/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [80.0]
#
# [Epoch 398/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [78.0]
#
# [Epoch 399/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 400/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 401/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 402/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 403/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 404/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 405/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 406/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [65.0]
#
# [Epoch 407/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 408/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 409/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 410/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 411/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 412/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 413/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 414/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 415/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 416/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [69.0]
#
# [Epoch 417/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 418/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 419/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [77.0]
#
# [Epoch 420/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 421/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 422/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [71.0]
#
# [Epoch 423/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 424/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 425/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 426/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [66.0]
#
# [Epoch 427/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 428/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 429/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 430/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [82.0]
#
# [Epoch 431/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [74.0]
#
# [Epoch 432/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [79.0]
#
# [Epoch 433/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [77.0]
#
# [Epoch 434/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [67.0]
#
# [Epoch 435/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 436/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 437/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 438/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [78.0]
#
# [Epoch 439/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 440/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [69.0]
#
# [Epoch 441/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [75.0]
#
# [Epoch 442/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [75.0]
#
# [Epoch 443/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [76.0]
#
# [Epoch 444/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 445/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 446/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 447/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 448/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 449/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [69.0]
#
# [Epoch 450/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 451/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 452/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [75.0]
#
# [Epoch 453/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 454/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 455/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 456/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [67.0]
#
# [Epoch 457/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 458/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [79.0]
#
# [Epoch 459/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [79.0]
#
# [Epoch 460/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 461/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 462/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 463/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 464/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 465/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [234.0]
#  \_loss [76.0]
#
# [Epoch 466/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [82.0]
#
# [Epoch 467/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 468/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [86.0]
#
# [Epoch 469/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [78.0]
#
# [Epoch 470/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 471/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [74.0]
#
# [Epoch 472/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 473/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 474/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 475/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 476/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 477/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 478/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 479/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [65.0]
#
# [Epoch 480/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 481/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 482/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [82.0]
#
# [Epoch 483/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [76.0]
#
# [Epoch 484/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 485/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 486/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 487/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 488/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 489/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 490/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 491/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 492/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 493/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 494/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 495/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 496/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 497/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 498/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 499/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 500/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 501/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [81.0]
#
# [Epoch 502/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 503/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [75.0]
#
# [Epoch 504/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 505/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 506/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 507/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 508/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 509/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 510/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 511/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 512/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [66.0]
#
# [Epoch 513/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 514/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 515/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 516/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 517/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 518/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 519/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 520/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 521/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 522/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 523/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 524/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 525/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 526/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 527/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 528/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 529/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 530/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [66.0]
#
# [Epoch 531/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 532/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [79.0]
#
# [Epoch 533/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 534/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 535/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [71.0]
#
# [Epoch 536/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 537/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 538/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 539/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 540/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 541/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 542/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 543/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 544/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 545/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 546/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 547/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 548/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [73.0]
#
# [Epoch 549/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 550/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 551/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 552/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 553/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 554/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 555/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 556/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 557/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 558/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [67.0]
#
# [Epoch 559/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 560/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 561/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 562/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 563/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 564/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 565/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [66.0]
#
# [Epoch 566/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [63.0]
#  \_loss [80.0]
#
# [Epoch 567/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [79.0]
#
# [Epoch 568/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 569/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 570/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 571/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 572/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 573/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 574/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 575/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 576/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 577/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 578/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 579/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 580/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 581/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 582/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 583/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 584/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 585/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [80.0]
#
# [Epoch 586/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [80.0]
#
# [Epoch 587/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 588/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 589/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 590/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 591/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 592/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 593/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 594/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 595/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 596/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 597/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [79.0]
#
# [Epoch 598/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 599/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 600/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 601/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 602/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 603/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 604/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 605/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 606/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 607/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 608/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [75.0]
#
# [Epoch 609/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 610/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [69.0]
#
# [Epoch 611/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 612/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [76.0]
#
# [Epoch 613/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [66.0]
#
# [Epoch 614/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 615/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [77.0]
#
# [Epoch 616/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 617/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 618/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 619/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [79.0]
#
# [Epoch 620/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 621/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 622/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 623/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [73.0]
#
# [Epoch 624/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 625/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [69.0]
#
# [Epoch 626/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 627/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [67.0]
#
# [Epoch 628/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 629/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [83.0]
#
# [Epoch 630/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 631/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 632/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 633/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 634/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 635/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [69.0]
#
# [Epoch 636/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [65.0]
#
# [Epoch 637/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 638/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 639/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 640/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 641/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 642/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [71.0]
#
# [Epoch 643/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 644/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 645/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 646/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 647/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 648/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 649/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 650/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 651/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [70.0]
#
# [Epoch 652/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [76.0]
#
# [Epoch 653/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [76.0]
#
# [Epoch 654/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 655/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 656/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 657/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 658/1000] >>>>>>>>>
#  Batch 0/0
# ...
#
# [Epoch 781/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 782/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 783/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [77.0]
#
# [Epoch 784/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [65.0]
#  \_loss [80.0]
#
# [Epoch 785/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [80.0]
#
# [Epoch 786/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 787/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 788/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 789/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 790/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 791/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 792/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 793/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [70.0]
#
# [Epoch 794/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [77.0]
#
# [Epoch 795/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 796/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 797/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 798/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 799/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 800/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [75.0]
#
# [Epoch 801/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 802/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 803/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 804/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 805/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 806/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 807/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 808/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [71.0]
#
# [Epoch 809/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 810/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 811/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 812/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 813/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 814/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [68.0]
#
# [Epoch 815/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 816/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 817/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 818/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 819/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 820/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 821/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 822/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 823/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [76.0]
#
# [Epoch 824/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 825/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [84.0]
#
# [Epoch 826/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [75.0]
#
# [Epoch 827/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 828/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 829/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 830/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 831/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [79.0]
#
# [Epoch 832/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 833/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 834/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 835/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 836/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 837/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 838/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 839/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 840/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 841/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 842/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [80.0]
#
# [Epoch 843/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 844/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 845/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 846/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 847/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 848/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 849/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 850/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 851/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 852/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 853/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 854/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 855/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [77.0]
#
# [Epoch 856/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [76.0]
#
# [Epoch 857/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 858/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 859/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 860/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [77.0]
#
# [Epoch 861/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 862/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 863/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 864/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 865/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 866/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 867/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [71.0]
#
# [Epoch 868/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [66.0]
#
# [Epoch 869/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 870/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 871/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [78.0]
#
# [Epoch 872/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [76.0]
#
# [Epoch 873/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 874/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [73.0]
#
# [Epoch 875/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 876/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 877/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 878/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 879/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [48.0]
#  \_loss [72.0]
#
# [Epoch 880/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [58.0]
#  \_loss [81.0]
#
# [Epoch 881/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 882/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 883/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 884/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [80.0]
#
# [Epoch 885/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 886/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [71.0]
#
# [Epoch 887/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [62.0]
#  \_loss [77.0]
#
# [Epoch 888/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 889/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 890/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 891/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [84.0]
#
# [Epoch 892/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 893/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [74.0]
#
# [Epoch 894/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 895/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [78.0]
#
# [Epoch 896/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 897/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 898/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [78.0]
#
# [Epoch 899/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 900/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 901/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 902/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 903/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [76.0]
#
# [Epoch 904/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 905/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 906/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [77.0]
#
# [Epoch 907/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 908/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 909/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 910/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 911/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 912/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 913/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 914/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [71.0]
#
# [Epoch 915/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [73.0]
#
# [Epoch 916/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 917/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 918/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [73.0]
#
# [Epoch 919/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 920/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [83.0]
#
# [Epoch 921/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 922/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [72.0]
#
# [Epoch 923/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [74.0]
#
# [Epoch 924/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [70.0]
#
# [Epoch 925/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 926/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 927/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 928/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [78.0]
#
# [Epoch 929/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [74.0]
#
# [Epoch 930/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 931/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 932/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [72.0]
#
# [Epoch 933/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [73.0]
#
# [Epoch 934/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 935/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 936/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [68.0]
#
# [Epoch 937/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [77.0]
#
# [Epoch 938/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 939/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [74.0]
#
# [Epoch 940/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [76.0]
#
# [Epoch 941/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [80.0]
#
# [Epoch 942/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [72.0]
#
# [Epoch 943/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 944/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [75.0]
#
# [Epoch 945/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 946/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 947/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 948/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 949/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [72.0]
#
# [Epoch 950/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 951/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [74.0]
#
# [Epoch 952/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [67.0]
#
# [Epoch 953/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 954/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 955/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 956/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 957/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [67.0]
#
# [Epoch 958/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [71.0]
#
# [Epoch 959/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 960/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [75.0]
#
# [Epoch 961/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [76.0]
#
# [Epoch 962/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [67.0]
#
# [Epoch 963/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [56.0]
#  \_loss [77.0]
#
# [Epoch 964/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 965/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [73.0]
#
# [Epoch 966/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [79.0]
#
# [Epoch 967/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]
#
# [Epoch 968/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 969/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [71.0]
#
# [Epoch 970/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [68.0]
#
# [Epoch 971/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [54.0]
#  \_loss [70.0]
#
# [Epoch 972/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 973/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 974/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [57.0]
#  \_loss [84.0]
#
# [Epoch 975/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [75.0]
#
# [Epoch 976/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [65.0]
#
# [Epoch 977/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 978/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [72.0]
#
# [Epoch 979/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [70.0]
#
# [Epoch 980/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [67.0]
#
# [Epoch 981/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [74.0]
#
# [Epoch 982/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 983/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [55.0]
#  \_loss [80.0]
#
# [Epoch 984/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [75.0]
#
# [Epoch 985/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [68.0]
#
# [Epoch 986/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [76.0]
#
# [Epoch 987/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [49.0]
#  \_loss [67.0]
#
# [Epoch 988/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [69.0]
#
# [Epoch 989/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [69.0]
#
# [Epoch 990/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [69.0]
#
# [Epoch 991/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [73.0]
#
# [Epoch 992/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [66.0]
#
# [Epoch 993/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [74.0]
#
# [Epoch 994/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [77.0]
#
# [Epoch 995/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 996/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [51.0]
#  \_loss [72.0]
#
# [Epoch 997/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [53.0]
#  \_loss [79.0]
#
# [Epoch 998/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [50.0]
#  \_loss [71.0]
#
# [Epoch 999/1000] >>>>>>>>>
#  Batch 0/0
#  \_val_loss [52.0]
#  \_loss [70.0]

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])

# %%
i = 0
j = -1
k = -1
x = vae.predict(x_train[:100])
plot.single(x_train[i, :50, :, 0])
plot.single(x[i, :50, :, 0])
plot.single(x_train[j, :50, :, 0])
plot.single(x[j, :50, :, 0])
plot.single(x_train[k, :50, :, 0])
plot.single(x[k, :50, :, 0])
# Out:
# m (40, 10)
# m (40, 10)
# m (40, 10)
# m (40, 10)
# m (40, 10)
# m (40, 10)

# %%
x = datagen.shuffle_3rd_dim_soft(x_train[:10], mutation_rate=0.5, scale=0.5, verbose=0)
plot.single(x_train[0,:,:,0])
plot.single(x[0,:,:,0])
x_ = vae.predict(x)
plot.single(x_[0,:,:,0])
# Out:
# m (40, 10)
# m (40, 10)
# m (40, 10)

# %%
x.shape
# Out:
# (9, 40, 10, 1)

# %%
# min: these pixels are 'always' active
m = x.min(axis=0)
plot.multi(m[:30,:,0])
# Out:
# m (30, 10)

# %%
# mean
m = x.mean(axis=0)
plot.single(m[:30,:,0])
# Out:
# m (30, 10)

# %% [markdown]
# ## Encoder + Generator
# A model to project inputs on the latent space

# %%
# build a model to project inputs on the latent space
encoder = Model(encoder_input, z_mean)

# %%
x_test.shape
# Out:
# (1, 40, 10, 1)

# %%
m = 100
x_train_encoded = encoder.predict(x_train[:m], batch_size=batch_size)
x_train_encoded.shape
# Out:
# (9, 2)

# %%
# y_test = range(x_train_encoded.shape[0])
y_test = np.concatenate([list(range(n)) for _ in range(int(m/n)+1)])[:m] / n
plt.figure(figsize=(6, 6))
plt.scatter(x_train_encoded[:, 0], x_train_encoded[:, 1], alpha=0.8, s=30) # c=y_test,

# %%
# display a 2D plot of the digit classes in the latent space
x_test_encoded = encoder.predict(x_test, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], alpha=0.6, s=30) # , c=y_test
# plt.colorbar()

# %%
# build a digit generator that can sample from the learned distribution
decoder_input = Input(shape=(latent_dim,))
_decoded = utils.composition(decoders, decoder_input, verbose=False)
generator = Model(decoder_input, _decoded)

# %%
# x_decoded[0].reshape(150,3)

# %%
x_train.shape
# Out:
# (9, 40, 10, 1)

# %%
min_y = 0.01
max_y = 0.5
plot.latent(generator, batch_size,
       n=8,
       m=3,
       crop_size=30,
       margin_top=1,
       margin_left=1,
       min_x=0.05,
       max_x=0.95,
       min_y=min_y,
       max_y=max_y)
# Out:
# (2,) [0. 0.]

# %%
min_y2 = max_y
plot.latent(generator, batch_size,
       n=8,
       m=3,
       crop_size=30,
       margin_top=1,
       margin_left=1,
       min_x=0.05,
       max_x=0.95,
       min_y=min_y2,
       max_y=0.95)
# Out:
# (2,) [0. 0.]
