# %%
import config
import os, numpy as np, pandas, sklearn
import mido
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## NN libs
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
import keras
from keras import regularizers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from keras.layers import Input, Dense, Activation, Conv1D, Conv2D, Dropout, Flatten
from keras.layers import Conv2DTranspose, Reshape, MaxPooling2D, UpSampling2D, UpSampling1D, MaxPooling1D
from keras.layers import LocallyConnected1D, LocallyConnected2D
from keras.layers import Input, LSTM, RepeatVector
from keras.models import Model
from keras.callbacks import TensorBoard
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# local libs
import config, models, functions
from data import data, midi, midi_generators as g
from utils import io, models_io
# Out:
#  Context :: namedtuple(
# [ max_t = float
# , dt = float
# , n_instances = int
# , note_length = int
# , bpm = float
# , tempo = float
# , ticks_per_beat = int
# ]

# %%
context = data.init()
# Out:
# Setting up params
#
#  >> Context(max_t=3.0, dt=0.1, n_instances=30, note_length=0.03, bpm=120.0, tempo=500000, ticks_per_beat=480)

# %%
# fn = (config.dataset_dir + '4-floor-120bpm.mid')
# mid = io.import_midifile(fn)

# %% [markdown]
# ## Setup a generator
#
# 1. What is the least amount of 'hidden' nodes needed to learn a straight rythm (e.g. 8th notes with different frequencies)
# 2. Can we create a model of a generic function sin(2 pi f t + phase)
#     - using x: t -> y: sin(2p t)
#     - using x: [f, t, phase] -> y: sin(2p f t + phase)
#     - using x: sin([t1, t2, t3) -> y: [f, t, phase]
#         - such a model should be able to learn complex patterns, such as sin(f1+p1) + sin(f2+p2) + sin(f3+p3)

# %%
n = 100
x_train = g.gen_data(context, n)
# x_train = np.zeros([10,100,127])
y_train = x_train
# Out:
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6937500000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.5312500000000004
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.84375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.45625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.529166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.959375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0333333333333337
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.583333333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.004166666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.55
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6583333333333337
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.345833333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.364583333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.5343750000000003
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.85625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.9281250000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.271875
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.0375000000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  6.652083333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.984375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9854166666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.220833333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0229166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6625000000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.34375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.202083333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.028125
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.875
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.3979166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.85625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.090625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.55
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.20625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.825
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.058333333333334
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0770833333333334
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.705208333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.84375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.109375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.545833333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6187500000000004
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  6.994791666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0187500000000003
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.077083333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.35625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.4375000000000004
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.594791666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.6625000000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.241666666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.988541666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.071875
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.3
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  9.213541666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  9.396875
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  7.861458333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.479166666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.775
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.1770833333333335
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.291666666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.4020833333333336
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.007291666666666
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.679166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.996874999999999
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.65625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.88125
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.73125
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.754166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6156250000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.60625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.3895833333333334
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.19375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.104166666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.1645833333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.409375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  9.638541666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0250000000000004
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.160416666666667
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.1895833333333337
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.89375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.9437500000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.090625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.420833333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9895833333333335
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.09375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.4125000000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  4.2250000000000005
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.637499999999999
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0875
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  5.45625
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.1750000000000003
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.234375
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  6.458333333333333
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.8177083333333335
#  |>  30

# %%
# [sum(x) for x in x_train]
x_train.shape
# Out:
# (100, 30, 4)

# %%
y_train = x_train
n_samples = x_train[0]
input_shape = x_train.shape[1:] # shape of a single sample
output_shape = y_train.shape[1:]
# output_length = y_train.shape[1]
# output_length = (y_train[0]).shape[0] # = length of an individual label
hidden_layer_length = 100
x_train.shape
# Out:
# (100, 30, 4)

# %%
def resolution_reducer(input_shape, amt=2):
    input_layer = Input(shape=input_shape)
    x = input_layer
    x = MaxPooling1D(pool_size=amt, strides=amt)(x)
    model = Model(inputs=input_layer, outputs=x)
    return model

reducer = resolution_reducer(input_shape,2)
reducer.summary()
# reducer.compile('adam',loss='mse')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 30, 4)             0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 15, 4)             0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
reducer.output_shape
# Out:
# (None, 15, 4)

# %%
# functional syntax: lambda x: lambda y: z
def encoder(input_shape, output_length, dropout=0.10):
    input_layer = Input(shape=input_shape)
    x = input_layer
    x = Flatten()(x)
#     x = Dense(output_length * 2, activation='relu')(x)
#     x = Dense(output_length * 2, activation='relu')(x)
    x = Dense(output_length, activation='sigmoid')(x)
#     x = Dense(output_length, activation='relu', activity_regularizer=regularizers.l1(10e-5))(x)
    #     model.add(Dropout(dropout))    
    model = Model(inputs=input_layer, outputs=x)
    return model


def decoder(input_length, output_shape, dropout=0.10):
    input_layer = Input(shape=(input_length,))
    x = input_layer
    shape = output_shape
    # shape = (10,100) # increase n dimensions
    x = Dense(np.prod(shape), activation='relu')(x) # 4*4*8 = 128
    x = Reshape(shape)(x)
#     x = UpSampling1D(10)(x)
    # make sure the conv layer increases the amount of dimensions
#     dims = keras.backend.int_shape(x)[1:]
#     n_steps = output_shape[0]
#     n_output_timesteps = output_shape[1]
#     filters = n_output_timesteps
#     conv_amt = 2
#     print('__+++==', n_output_timesteps)
#     x = Conv1D(filters, kernel_size=4, strides=2, activation='relu')(x) # 50,100

    dims = keras.backend.int_shape(x)[1:]
#     x = UpSampling1D(dims[0] * 2)(x)
    x = Dense(output_shape[1], activation='relu')(x)
#     x = Dense(output_shape[1], activation='relu')(x)
#     x = Dense(output_shape[1], activation='relu')(x)
    #     x = LocallyConnected1D(output_shape[1], kernel_size=1, activation='relu')(x)
    # x = Dense(output_length, activation='softmax')(x)
    model = Model(inputs=input_layer, outputs=x)
    #     model.add(Dropout(dropout))
    return model


def autoencoder(input_shape, output_shape, hidden_layer_length=10, dropout=0.10, verbose=False):
    input_ = Input(shape=input_shape)
    reducer = resolution_reducer(input_shape,1)
    if verbose:
        reducer.summary()
    input_shape = reducer.output_shape[1:]
    encode = encoder(input_shape, hidden_layer_length, dropout)
    if verbose:
        encode.summary()
    decode = decoder(hidden_layer_length, output_shape, dropout)
    if verbose:
        decode.summary()
    model = Model(input_, decode(encode(reducer(input_))))
    return encode, decode, reducer, model


dropout = 0.
encoder, decoder, reducer, auto = autoencoder(input_shape, output_shape, hidden_layer_length, dropout, True)
# summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 30, 4)             0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 30, 4)             0
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 30, 4)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               12100
# =================================================================
# Total params: 12,100
# Trainable params: 12,100
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               12120
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 30, 4)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30, 4)             20
# =================================================================
# Total params: 12,140
# Trainable params: 12,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = ['accuracy','mse','categorical_crossentropy']
loss = 'binary_crossentropy'# binary_crossentropy categorical_crossentropy
optimizer = 'adadelta'
auto.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
batch_size = 16
# n epochs = n iterations over all the training data
epochs = 15

# %%
auto.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[TensorBoard(log_dir=config.tmp_log_dir)])
# model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size,
#           validation_split=1/6, callbacks=[TensorBoard(log_dir=config.tmp_log_dir)])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 0s 960us/step - loss: 0.2930 - acc: 0.9719 - mean_squared_error: 0.0304 - categorical_crossentropy: nan
# Epoch 2/50
# 100/100 [==============================] - 0s 183us/step - loss: 0.2563 - acc: 0.9836 - mean_squared_error: 0.0179 - categorical_crossentropy: nan
# Epoch 3/50
# 100/100 [==============================] - 0s 247us/step - loss: 0.2118 - acc: 0.9836 - mean_squared_error: 0.0165 - categorical_crossentropy: nan
# Epoch 4/50
# 100/100 [==============================] - 0s 201us/step - loss: 0.1491 - acc: 0.9836 - mean_squared_error: 0.0160 - categorical_crossentropy: nan
# Epoch 5/50
# 100/100 [==============================] - 0s 306us/step - loss: 0.0920 - acc: 0.9836 - mean_squared_error: 0.0158 - categorical_crossentropy: nan
# Epoch 6/50
# 100/100 [==============================] - 0s 217us/step - loss: 0.0901 - acc: 0.9836 - mean_squared_error: 0.0156 - categorical_crossentropy: nan
# Epoch 7/50
# 100/100 [==============================] - 0s 265us/step - loss: 0.0892 - acc: 0.9836 - mean_squared_error: 0.0156 - categorical_crossentropy: nan
# Epoch 8/50
# 100/100 [==============================] - 0s 280us/step - loss: 0.0885 - acc: 0.9836 - mean_squared_error: 0.0155 - categorical_crossentropy: nan
# Epoch 9/50
# 100/100 [==============================] - 0s 242us/step - loss: 0.0883 - acc: 0.9836 - mean_squared_error: 0.0155 - categorical_crossentropy: nan
# Epoch 10/50
# 100/100 [==============================] - 0s 203us/step - loss: 0.0878 - acc: 0.9836 - mean_squared_error: 0.0155 - categorical_crossentropy: nan
# Epoch 11/50
# 100/100 [==============================] - 0s 196us/step - loss: 0.0873 - acc: 0.9836 - mean_squared_error: 0.0154 - categorical_crossentropy: nan
# Epoch 12/50
# 100/100 [==============================] - 0s 263us/step - loss: 0.0868 - acc: 0.9836 - mean_squared_error: 0.0154 - categorical_crossentropy: nan
# Epoch 13/50
# 100/100 [==============================] - 0s 196us/step - loss: 0.0867 - acc: 0.9836 - mean_squared_error: 0.0154 - categorical_crossentropy: nan
# Epoch 14/50
# 100/100 [==============================] - 0s 270us/step - loss: 0.0862 - acc: 0.9836 - mean_squared_error: 0.0153 - categorical_crossentropy: nan
# Epoch 15/50
# 100/100 [==============================] - 0s 234us/step - loss: 0.0859 - acc: 0.9836 - mean_squared_error: 0.0153 - categorical_crossentropy: nan
# Epoch 16/50
# 100/100 [==============================] - 0s 272us/step - loss: 0.0855 - acc: 0.9836 - mean_squared_error: 0.0153 - categorical_crossentropy: nan
# Epoch 17/50
# 100/100 [==============================] - 0s 201us/step - loss: 0.0852 - acc: 0.9836 - mean_squared_error: 0.0152 - categorical_crossentropy: nan
# Epoch 18/50
# 100/100 [==============================] - 0s 239us/step - loss: 0.0848 - acc: 0.9836 - mean_squared_error: 0.0152 - categorical_crossentropy: nan
# Epoch 19/50
# 100/100 [==============================] - 0s 197us/step - loss: 0.0845 - acc: 0.9836 - mean_squared_error: 0.0152 - categorical_crossentropy: nan
# Epoch 20/50
# 100/100 [==============================] - 0s 255us/step - loss: 0.0840 - acc: 0.9836 - mean_squared_error: 0.0151 - categorical_crossentropy: nan
# Epoch 21/50
# 100/100 [==============================] - 0s 198us/step - loss: 0.0836 - acc: 0.9836 - mean_squared_error: 0.0151 - categorical_crossentropy: nan
# Epoch 22/50
# 100/100 [==============================] - 0s 212us/step - loss: 0.0831 - acc: 0.9836 - mean_squared_error: 0.0150 - categorical_crossentropy: nan
# Epoch 23/50
# 100/100 [==============================] - 0s 227us/step - loss: 0.0827 - acc: 0.9836 - mean_squared_error: 0.0150 - categorical_crossentropy: nan
# Epoch 24/50
# 100/100 [==============================] - 0s 244us/step - loss: 0.0820 - acc: 0.9836 - mean_squared_error: 0.0149 - categorical_crossentropy: nan
# Epoch 25/50
# 100/100 [==============================] - 0s 233us/step - loss: 0.0814 - acc: 0.9836 - mean_squared_error: 0.0148 - categorical_crossentropy: nan
# Epoch 26/50
# 100/100 [==============================] - 0s 203us/step - loss: 0.0806 - acc: 0.9836 - mean_squared_error: 0.0147 - categorical_crossentropy: nan
# Epoch 27/50
# 100/100 [==============================] - 0s 217us/step - loss: 0.0799 - acc: 0.9836 - mean_squared_error: 0.0146 - categorical_crossentropy: nan
# Epoch 28/50
# 100/100 [==============================] - 0s 317us/step - loss: 0.0791 - acc: 0.9836 - mean_squared_error: 0.0144 - categorical_crossentropy: nan
# Epoch 29/50
# 100/100 [==============================] - 0s 221us/step - loss: 0.0783 - acc: 0.9836 - mean_squared_error: 0.0142 - categorical_crossentropy: nan
# Epoch 30/50
# 100/100 [==============================] - 0s 251us/step - loss: 0.0774 - acc: 0.9836 - mean_squared_error: 0.0140 - categorical_crossentropy: nan
# Epoch 31/50
# 100/100 [==============================] - 0s 235us/step - loss: 0.0765 - acc: 0.9836 - mean_squared_error: 0.0137 - categorical_crossentropy: nan
# Epoch 32/50
# 100/100 [==============================] - 0s 218us/step - loss: 0.0755 - acc: 0.9836 - mean_squared_error: 0.0134 - categorical_crossentropy: nan
# Epoch 33/50
# 100/100 [==============================] - 0s 217us/step - loss: 0.0743 - acc: 0.9836 - mean_squared_error: 0.0130 - categorical_crossentropy: nan
# Epoch 34/50
# 100/100 [==============================] - 0s 199us/step - loss: 0.0732 - acc: 0.9836 - mean_squared_error: 0.0126 - categorical_crossentropy: nan
# Epoch 35/50
# 100/100 [==============================] - 0s 264us/step - loss: 0.0719 - acc: 0.9836 - mean_squared_error: 0.0121 - categorical_crossentropy: nan
# Epoch 36/50
# 100/100 [==============================] - 0s 213us/step - loss: 0.0705 - acc: 0.9836 - mean_squared_error: 0.0115 - categorical_crossentropy: nan
# Epoch 37/50
# 100/100 [==============================] - 0s 264us/step - loss: 0.0691 - acc: 0.9836 - mean_squared_error: 0.0110 - categorical_crossentropy: nan
# Epoch 38/50
# 100/100 [==============================] - 0s 189us/step - loss: 0.0674 - acc: 0.9836 - mean_squared_error: 0.0104 - categorical_crossentropy: nan
# Epoch 39/50
# 100/100 [==============================] - 0s 189us/step - loss: 0.0660 - acc: 0.9860 - mean_squared_error: 0.0099 - categorical_crossentropy: nan
# Epoch 40/50
# 100/100 [==============================] - 0s 205us/step - loss: 0.0650 - acc: 0.9919 - mean_squared_error: 0.0094 - categorical_crossentropy: nan
# Epoch 41/50
# 100/100 [==============================] - 0s 249us/step - loss: 0.0640 - acc: 0.9919 - mean_squared_error: 0.0089 - categorical_crossentropy: nan
# Epoch 42/50
# 100/100 [==============================] - 0s 241us/step - loss: 0.0631 - acc: 0.9919 - mean_squared_error: 0.0085 - categorical_crossentropy: nan
# Epoch 43/50
# 100/100 [==============================] - 0s 223us/step - loss: 0.0622 - acc: 0.9919 - mean_squared_error: 0.0082 - categorical_crossentropy: nan
# Epoch 44/50
# 100/100 [==============================] - 0s 224us/step - loss: 0.0614 - acc: 0.9919 - mean_squared_error: 0.0080 - categorical_crossentropy: nan
# Epoch 45/50
# 100/100 [==============================] - 0s 278us/step - loss: 0.0606 - acc: 0.9919 - mean_squared_error: 0.0078 - categorical_crossentropy: nan
# Epoch 46/50
# 100/100 [==============================] - 0s 199us/step - loss: 0.0602 - acc: 0.9919 - mean_squared_error: 0.0077 - categorical_crossentropy: nan
# Epoch 47/50
# 100/100 [==============================] - 0s 216us/step - loss: 0.0597 - acc: 0.9919 - mean_squared_error: 0.0076 - categorical_crossentropy: nan
# Epoch 48/50
# 100/100 [==============================] - 0s 219us/step - loss: 0.0597 - acc: 0.9919 - mean_squared_error: 0.0076 - categorical_crossentropy: nan
# Epoch 49/50
# 100/100 [==============================] - 0s 249us/step - loss: 0.0593 - acc: 0.9919 - mean_squared_error: 0.0076 - categorical_crossentropy: nan
# Epoch 50/50
# 100/100 [==============================] - 0s 187us/step - loss: 0.0594 - acc: 0.9919 - mean_squared_error: 0.0076 - categorical_crossentropy: nan

# %%
mid1 = g.render_midi(context, f=2)
mid2 = g.render_midi(context, f=3)
x_test = np.stack([midi.encode(context, m) for m in [mid1,mid2]])
# Out:
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0
#  |>  30
# [DEBUG] >
#  |>  WARNING
#  |>  type not == 0
# [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000001
#  |>  30

# %%
latent = encoder.predict(reducer.predict(x_test))
latent.shape
# Out:
# (2, 100)

# %%
latent.shape
# Out:
# (2, 100)

# %%
maxx = np.maximum(latent[0],latent[1])
maxx.shape
# Out:
# (100,)

# %%
latent[0].shape
# Out:
# (100,)

# %%
arrays = decoder.predict(np.stack([latent[1]]))
arrays.shape
# Out:
# (1, 30, 4)

# %%
mid = midi.decode_track(context, arrays[0])
# Out:
# [INFO] :
#  |  len, max_t
#  |  2.8302083333333337
#  |  3.0

# %%
dn = config.export_dir
io.export_midifile(mid1, dn + 'mid1.mid')
# io.export_midifile(mid2, dn + 'mid2.mid')
io.export_midifile(mid, dn + 'mid_generated.mid')

# %%
mid
# Out:
# <midi file None type 1, 1 tracks, 32 messages>
