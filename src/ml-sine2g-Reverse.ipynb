# %%
import config
import os, numpy as np, pandas, sklearn, scipy.signal as signal
import mido
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## NN libs
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
import keras
from keras import regularizers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from keras.layers import Input, Dense, Activation, Conv1D, Conv2D, Dropout, Flatten
from keras.layers import Conv2DTranspose, Reshape, MaxPooling2D, UpSampling2D, UpSampling1D, MaxPooling1D
from keras.layers import LocallyConnected1D, LocallyConnected2D
from keras.layers import Input, LSTM, RepeatVector
from keras.models import Model
from keras.callbacks import TensorBoard
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# local libs
import config, models, functions
from data import data, midi, midi_generators as g
from utils import io, models_io, utils
# Out:
#  Context :: namedtuple(
# [ max_t = float
# , dt = float
# , n_instances = int
# , note_length = int
# , bpm = float
# , tempo = float
# , ticks_per_beat = int
# ]

# %%
n = 10
multiTrack = False
context, x_train, labels = data.import_data(data.init(), n, multiTrack=multiTrack)
# Out:
# Setting up params
#
# max min f 25.0 0.3333333333333333
#  >> Context(max_t=3.0, dt=0.02, n_instances=150, note_length=0.03, bpm=120.0, tempo=500000, ticks_per_beat=480)
# Importing midi-data
#
#  [INFO] :
#  |  reading file: ../datasets/examples/01 16th Snare.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/01 8th Cym.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/01 8th Hat.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/02 8th Cym.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/114_LetsDance_DavidBowie1.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/127_SweetChildOMine_GunsAndRoses1.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/92_GiveItAway_TheRedHotChiliPeppers.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/94_Creep_Radiohead2.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/bossa 1.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/bossa 2.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/bossa 3.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/bossa 4.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/G3.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/G4.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/G5.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/G6.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/simple-shuffle-120.mid
#  [INFO] :
#  |  reading file: ../datasets/examples/simple-straight-120.mid
#
# Encoding midi-data
#  [<midi file '../datasets/examples/01 16th Snare.mid' type 0, 1 tracks, 182 messages>, <midi file '../datasets/examples/01 8th Cym.mid' type 0, 1 tracks, 68 messages>, <midi file '../datasets/examples/01 8th Hat.mid' type 0, 1 tracks, 60 messages>, <midi file '../datasets/examples/02 8th Cym.mid' type 0, 1 tracks, 72 messages>, <midi file '../datasets/examples/114_LetsDance_DavidBowie1.mid' type 0, 1 tracks, 76 messages>, <midi file '../datasets/examples/127_SweetChildOMine_GunsAndRoses1.mid' type 0, 1 tracks, 226 messages>, <midi file '../datasets/examples/92_GiveItAway_TheRedHotChiliPeppers.mid' type 0, 1 tracks, 132 messages>, <midi file '../datasets/examples/94_Creep_Radiohead2.mid' type 0, 1 tracks, 126 messages>, <midi file '../datasets/examples/bossa 1.mid' type 0, 1 tracks, 40 messages>, <midi file '../datasets/examples/bossa 2.mid' type 0, 1 tracks, 38 messages>, <midi file '../datasets/examples/bossa 3.mid' type 0, 1 tracks, 34 messages>, <midi file '../datasets/examples/bossa 4.mid' type 0, 1 tracks, 42 messages>, <midi file '../datasets/examples/G3.mid' type 0, 1 tracks, 58 messages>, <midi file '../datasets/examples/G4.mid' type 0, 1 tracks, 111 messages>, <midi file '../datasets/examples/G5.mid' type 0, 1 tracks, 85 messages>, <midi file '../datasets/examples/G6.mid' type 0, 1 tracks, 107 messages>, <midi file '../datasets/examples/simple-shuffle-120.mid' type 0, 1 tracks, 68 messages>, <midi file '../datasets/examples/simple-straight-120.mid' type 0, 1 tracks, 68 messages>]
# > -> multi-track = False
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.999999999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9999999999999996
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0057662250000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9932662375
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.6615348
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9961508500000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0
#  |>  150

# %%
n = 100
min_f = 3
max_f = 20
# x_train = g.gen_data(context, n, max_f=max_f, min_f=min_f)
x_train = g.gen_data_complex(context, n, max_f=max_f, min_f=min_f, multiTrack=multiTrack)
# Out:
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000044
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0229166666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.004166666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0062500000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000017
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.999999999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937499999999995
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666672
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.00729166666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999984
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666675
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333324
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333345
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666644
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333324
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.022916666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000037
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666696
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333327
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333339
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.006250000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0177083333333377
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.017708333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333367
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999988
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.015625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0291666666666712
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99375
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0104166666666696
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666625
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.013541666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666656
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000044
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333313
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999983
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666656
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.006249999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333338
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.006250000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333322
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000017
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0375000000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666687
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333322
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.006250000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666742
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333373
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000012
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996874999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000006
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.004166666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000013
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.006249999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0229166666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000012
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000012
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.014583333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333354
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996874999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000057
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333355
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0125000000000006
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.004166666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333307
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000024
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000055
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99375
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000016
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0312500000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000044
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000017
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.00625
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.013541666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333386
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0062500000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0083333333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333345
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333327
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0114583333333376
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000017
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99583333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.00416666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0083333333333324
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666693
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666693
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000044
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0114583333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0156250000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0145833333333303
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0083333333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000012
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.999999999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003124999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999988
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000007
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99166666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666705
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333331
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666707
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996874999999996
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031249999999976
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333316
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0145833333333365
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99166666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666696
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000025
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666702
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666674
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333353
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333306
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666644
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333355
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666664
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937499999999972
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.008333333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333375
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333353
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093749999999995
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000006
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666675
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999993
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0104166666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0145833333333343
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666677
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666674
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666671
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000005
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999997
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999974
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333347
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333346
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666675
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333363
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000026
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333363
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000023
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666643
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333322
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99166666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666696
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937499999999995
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666684
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666653
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99479166666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333343
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666656
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0104166666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333357
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0083333333333324
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0166666666666657
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0229166666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333326
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.037500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333353
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333355
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000005
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666686
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333368
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333344
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999993
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0020833333333328
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0343749999999976
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0187500000000007
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333347
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333353
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.998958333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031249999999994
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0104166666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666702
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99479166666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666686
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000033
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666694
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000052
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.005208333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666645
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000007
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0229166666666685
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0135416666666686
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999974
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999997
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.999999999999998
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333345
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333362
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333332
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333345
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0333333333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333347
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0062500000000028
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666687
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666632
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9937500000000004
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99479166666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0093750000000017
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333384
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666636
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999998
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333355
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333333
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.997916666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333343
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333365
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333337
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0041666666666695
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990624999999997
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.994791666666665
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0197916666666704
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.007291666666668
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000015
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.004166666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666663
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333327
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.003125000000006
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666675
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0062500000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0031250000000016
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999993
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666636
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.004166666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993750000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0166666666666684
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906250000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666672
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999993
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.99479166666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0010416666666657
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.018750000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9916666666666667
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.009375000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.002083333333334
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.995833333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0062500000000014
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0072916666666676
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9927083333333364
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000003
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000024
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0052083333333335
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968749999999975
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.001041666666669
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666703
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666687
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9968750000000033
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666686
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.993749999999999
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0000000000000036
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9989583333333365
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9906249999999996
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.000000000000002
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.991666666666666
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.990625000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9979166666666672
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9958333333333327
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.992708333333336
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.9947916666666736
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  2.996875000000001
#  |>  150
#  [DEBUG] >
#  |>  to_array: msg.time > max_t; t, n
#  |>  3.0208333333333357
#  |>  150

# %%
x_train.shape
# Out:
# (1336, 150, 1)

# %%
plt.plot(x_train[0,:100])

# %%
n_samples = x_train[0]
input_shape = x_train.shape[1:] # shape of a single sample
output_shape = y_train.shape[1:] # shape of a single sample
# output_length = y_train.shape[1:][0]
hidden_layer_length = 10
input_shape
# Out:
# (150, 1)

# %%
output_shape
# Out:
# (149, 1)

# %%
num_encoder_tokens = x_train.shape[-1]
num_decoder_tokens = y_train.shape[-1]
latent_dim = 100
# latent_dim = 1

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
# x = Dense(100)(encoder_inputs)
x = LSTM(latent_dim, return_sequences=True)(encoder_inputs)
x = Dense(latent_dim)(x)
x = Dropout(0.1)(x)
encoder_outputs = x
encoder_model = Model(encoder_inputs, encoder_outputs)

decoder_inputs = Input(shape=(None, latent_dim))
x = LSTM(latent_dim, return_sequences=True, go_backwards=True)(decoder_inputs)
# x = Conv1D(100, 2, strides=2, activation='relu')(x)
x = Dropout(0.1)(x)
x = Dense(num_decoder_tokens * 100, activation='relu')(x)
x = Dense(num_decoder_tokens * 100, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(num_decoder_tokens)(x)
decoder_outputs = x
decoder_model = Model(decoder_inputs, decoder_outputs)

model = Model(encoder_inputs, decoder_model(encoder_model(encoder_inputs)))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_55 (InputLayer)        (None, None, 1)           0
# _________________________________________________________________
# model_82 (Model)             (None, None, 64)          21056
# _________________________________________________________________
# model_83 (Model)             (None, None, 1)           49725
# =================================================================
# Total params: 70,781
# Trainable params: 70,781
# Non-trainable params: 0
# _________________________________________________________________

# %%
# encoder_model.summary()
decoder_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_56 (InputLayer)        (None, None, 64)          0
# _________________________________________________________________
# lstm_56 (LSTM)               (None, None, 64)          33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 64)          0
# _________________________________________________________________
# dense_74 (Dense)             (None, None, 100)         6500
# _________________________________________________________________
# dense_75 (Dense)             (None, None, 100)         10100
# _________________________________________________________________
# dropout_3 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# dense_76 (Dense)             (None, None, 1)           101
# =================================================================
# Total params: 49,725
# Trainable params: 49,725
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = ['accuracy','mse','binary_crossentropy']
loss = 'binary_crossentropy'# binary_crossentropy categorical_crossentropy sparse_categorical_crossentropy
optimizer = 'rmsprop' # adam adadelta rmsprop nadam
# keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
model.compile(optimizer=optimizer, loss=loss, metrics=['mse', 'mae', 'accuracy'])#, metrics=metrics)

# %%
batch_size = 32
epochs = 15

# %%
callbacks = []
# callbacks = [TensorBoard(log_dir=config.tmp_log_dir)]
vs = 1/6
m = 100
# model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[TensorBoard(log_dir=config.tmp_log_dir)])
history = model.fit(x_train[:m], x_train[:m], epochs=epochs, batch_size=batch_size,
          validation_split=vs, callbacks=callbacks)
# Out:
# Train on 83 samples, validate on 17 samples
# Epoch 1/15
# 83/83 [==============================] - 7s 85ms/step - loss: 2.2720 - mean_squared_error: 0.2841 - mean_absolute_error: 0.3370 - acc: 0.6839 - val_loss: 0.8036 - val_mean_squared_error: 0.2819 - val_mean_absolute_error: 0.4040 - val_acc: 0.6224
# Epoch 2/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6840 - mean_squared_error: 0.2349 - mean_absolute_error: 0.3628 - acc: 0.6839 - val_loss: 0.6880 - val_mean_squared_error: 0.2449 - val_mean_absolute_error: 0.4200 - val_acc: 0.6224
# Epoch 3/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.6163 - mean_squared_error: 0.2131 - mean_absolute_error: 0.3860 - acc: 0.6839 - val_loss: 0.6405 - val_mean_squared_error: 0.2249 - val_mean_absolute_error: 0.4340 - val_acc: 0.6282
# Epoch 4/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5974 - mean_squared_error: 0.2054 - mean_absolute_error: 0.4043 - acc: 0.6847 - val_loss: 0.6307 - val_mean_squared_error: 0.2202 - val_mean_absolute_error: 0.4407 - val_acc: 0.6420
# Epoch 5/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5937 - mean_squared_error: 0.2037 - mean_absolute_error: 0.4109 - acc: 0.6873 - val_loss: 0.6293 - val_mean_squared_error: 0.2195 - val_mean_absolute_error: 0.4414 - val_acc: 0.6459
# Epoch 6/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5921 - mean_squared_error: 0.2029 - mean_absolute_error: 0.4109 - acc: 0.6876 - val_loss: 0.6292 - val_mean_squared_error: 0.2195 - val_mean_absolute_error: 0.4394 - val_acc: 0.6459
# Epoch 7/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5908 - mean_squared_error: 0.2025 - mean_absolute_error: 0.4085 - acc: 0.6855 - val_loss: 0.6287 - val_mean_squared_error: 0.2193 - val_mean_absolute_error: 0.4386 - val_acc: 0.6478
# Epoch 8/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5911 - mean_squared_error: 0.2026 - mean_absolute_error: 0.4076 - acc: 0.6837 - val_loss: 0.6276 - val_mean_squared_error: 0.2187 - val_mean_absolute_error: 0.4394 - val_acc: 0.6486
# Epoch 9/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5919 - mean_squared_error: 0.2030 - mean_absolute_error: 0.4084 - acc: 0.6857 - val_loss: 0.6280 - val_mean_squared_error: 0.2190 - val_mean_absolute_error: 0.4365 - val_acc: 0.6486
# Epoch 10/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5897 - mean_squared_error: 0.2021 - mean_absolute_error: 0.4061 - acc: 0.6848 - val_loss: 0.6279 - val_mean_squared_error: 0.2189 - val_mean_absolute_error: 0.4346 - val_acc: 0.6490
# Epoch 11/15
# 83/83 [==============================] - 1s 8ms/step - loss: 0.5878 - mean_squared_error: 0.2014 - mean_absolute_error: 0.4037 - acc: 0.6875 - val_loss: 0.6292 - val_mean_squared_error: 0.2195 - val_mean_absolute_error: 0.4314 - val_acc: 0.6467
# Epoch 12/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5893 - mean_squared_error: 0.2021 - mean_absolute_error: 0.4010 - acc: 0.6849 - val_loss: 0.6281 - val_mean_squared_error: 0.2189 - val_mean_absolute_error: 0.4391 - val_acc: 0.6561
# Epoch 13/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5882 - mean_squared_error: 0.2018 - mean_absolute_error: 0.4006 - acc: 0.6880 - val_loss: 0.6270 - val_mean_squared_error: 0.2185 - val_mean_absolute_error: 0.4323 - val_acc: 0.6482
# Epoch 14/15
# 83/83 [==============================] - 1s 9ms/step - loss: 0.5858 - mean_squared_error: 0.2008 - mean_absolute_error: 0.3998 - acc: 0.6882 - val_loss: 0.6267 - val_mean_squared_error: 0.2184 - val_mean_absolute_error: 0.4316 - val_acc: 0.6482
# Epoch 15/15
# 83/83 [==============================] - 1s 10ms/step - loss: 0.5875 - mean_squared_error: 0.2015 - mean_absolute_error: 0.3989 - acc: 0.6867 - val_loss: 0.6436 - val_mean_squared_error: 0.2251 - val_mean_absolute_error: 0.4446 - val_acc: 0.6439

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])

# %%
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])

# %%
# plt.plot(history.history['binary_crossentropy'])
# plt.plot(history.history['val_binary_crossentropy'])

# %%
z = encoder_model.predict(x_train[:2])
z.shape
# Out:
# (2, 150, 64)

# %%
results = model.predict(x_train[:10])
results.shape
# Out:
# (10, 150, 1)

# %%
plt.plot(x_train[0,:100,:])
plt.plot(results[0,:100,:])

# %%
n1 = 30
i = 0
plt.subplot(211)
plt.plot(np.arange(n1), results[i][:n1])
plt.plot([0.5] * n1) # midi.MIDI_NOISE_FLOOR
plt.ylim(ymin=0, ymax=1)
plt.subplot(212)

plt.plot(np.arange(n1), x_train[i, :n1])
plt.plot([0.5] * n1) # midi.MIDI_NOISE_FLOOR
plt.ylim(ymin=0, ymax=1)
# Out:
# (0, 1)

# %%
mid = midi.decode_track(context, result)
dn = config.dataset_dir
# io.export_midifile(mid, dn + 'song_seq-seq.mid')

# %%
results = []
latent_samples = []
for seq in x_test[-2:]:
    encoded = encode_sequence(np.stack([seq]))
    latent_samples.append(encoded)
    result = decode_sequence(encoded, encoder_model, decoder_model)
    results.append(result)
results[0].shape

# %%
len(encoded)

# %%
encoded[0].shape

# %%
plt.plot(encoded[0][0,:10])
plt.plot(encoded[1][0,:10])

# %%
e = np.array(latent_samples)
e.shape

# %%
# reduce dimensionality
# e = e.reshape(e.shape[0],2,e.shape[-1])
e.shape

# %%
e1.mean(axis=0).shape

# %%
# new = e.transpose().mean(axis=1).transpose()
e1 = e[:,0] # state h
e2 = e[:,1] # state c
new = [e1.mean(axis=0), e2.mean(axis=0)]
# new = [[e[:,i].mean(axis=0)] for i in [0,1]]
plt.plot(new[0][0][:10])
len(new)

# %%
e1.mean(axis=0).shape

# %%
l[0].shape

# %%
l = latent_samples[0]
len(l) # latent_sample :: (x,1,64)

# %%
# new_ = decode_sequence(latent_samples[0], encoder_model, decoder_model)
new_ = decode_sequence(new, encoder_model, decoder_model)

# %%
new_.shape

# %%
plt.plot(new_[:100])

# %%
plt.plot(results[0][:100])

# %%
# results[0]

# %%
mid_new = midi.decode_track(context, results[0])
io.export_midifile(mid_new, config.export_dir + 'real_mid_new_lstm.mid')

# %% [markdown]
# ## Alt
# Without teacher forcing https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
#
#
# <i>"In some niche cases you may not be able to use teacher forcing, because you don't have access to the full target sequences, e.g. if you are doing online training on very long sequences, where buffering complete input-target pairs would be impossible. In that case, you may want to do training by reinjecting the decoder's predictions into the decoder's input, just like we were doing for inference.
#
# You can achieve this by building a model that hard-codes the output reinjection loop: "</i>

# %%
from keras.layers import Lambda
from keras import backend as K

# The first part is unchanged
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder(encoder_inputs)
states = [state_h, state_c]

# Set up the decoder, which will only process one timestep at a time.
decoder_inputs = Input(shape=(1, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
# output will be a probability distribution over the vectors
decoder_dense = Dense(num_decoder_tokens, activation='softmax')

all_outputs = []
inputs = decoder_inputs
max_decoder_seq_length = 100
for _ in range(max_decoder_seq_length):
    # Run the decoder on one timestep
    outputs, state_h, state_c = decoder_lstm(inputs,
                                             initial_state=states)
    outputs = decoder_dense(outputs)
    # Store the current prediction (we will concatenate all predictions later)
    all_outputs.append(outputs)
    # Reinject the outputs as inputs for the next loop iteration
    # as well as update the states
    inputs = outputs
    states = [state_h, state_c]

# Concatenate all predictions
decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)

# Define and compile model as previously
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.summary()

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# Prepare decoder input data that just contains the start character
# Note that we could have made it a constant hard-coded in the model
decoder_input_data = np.zeros((x_train.shape[0], 1, num_decoder_tokens))

# Train model as previously
model.fit([x_train,y_train], z_train, epochs=10, batch_size=batch_size,
          validation_split=0.2, callbacks=callbacks)

# %%
x_test.shape

# %%
# x_test, y_test = gen_xy_sin_to_f(3, f=2)

# %%
results = model.predict([x_test,x_test])
results.shape

# %%
# the 'true' results
i = 0
selection = int(x_test.shape[1] * 1)
full = np.concatenate([x_test[i,-selection:],y_test[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)

# %%
# predicted results
i = 0
full = np.concatenate([x_test[i,-selection:],results[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)

# %%
i = 2
selection = int(x_test.shape[1] * 1)
full = np.concatenate([x_test[i,-selection:],results[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)

# %%
i = 0
selection = 1
full = np.concatenate([x_test[i,-selection:],results[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)
