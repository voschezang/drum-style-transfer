# %%
import config
import os, numpy as np, pandas, sklearn, scipy.signal as signal
import mido
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## NN libs
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
import keras
from keras import regularizers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.optimizers import SGD, Adam
from keras.layers import Input, Dense, Activation, Conv1D, Conv2D, Dropout, Flatten
from keras.layers import Conv2DTranspose, Reshape, MaxPooling2D, UpSampling2D, UpSampling1D, MaxPooling1D
from keras.layers import LocallyConnected1D, LocallyConnected2D
from keras.layers import Input, LSTM, RepeatVector
from keras.models import Model
from keras.callbacks import TensorBoard
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# local libs
import config, models, functions
from data import data, midi, midi_generators as g
from utils import io, models_io, utils
# Out:
#  Context :: namedtuple(
# [ max_t = float
# , dt = float
# , n_instances = int
# , note_length = int
# , bpm = float
# , tempo = float
# , ticks_per_beat = int
# ]

# %%
context = data.init()
# Out:
# Setting up params
#
#  >> Context(max_t=3.0, dt=0.1, n_instances=30, note_length=0.03, bpm=120.0, tempo=500000, ticks_per_beat=480)

# %% [markdown]
# ## Setup a generator
#
# 1. What is the least amount of 'hidden' nodes needed to learn a straight rythm (e.g. 8th notes with different frequencies)
# 2. Can we create a model of a generic function sin(2 pi f t + phase)
#     - using x: t -> y: sin(2p t)
#     - using x: [f, t, phase] -> y: sin(2p f t + phase)
#     - using x: sin([t1, t2, t3) -> y: [f, t, phase]
#         - such a model should be able to learn complex patterns, such as sin(f1+p1) + sin(f2+p2) + sin(f3+p3)

# %% [markdown]
# Here - decoder: x -> sin(x)

# %%
def gen_xy_sin_to_f(n_samples=500, n_t=100, f=None, dt=0.01):
    # x_train = array (unique_samples, xs_over_t, sin(xs))
    # y_train = array (unique_samples, xs_over_t, sin(xs + dx))
    max_t = n_t * dt
    min_f = utils.min_f(max_t)
    max_f = utils.max_f(dt)
    print('allowed min max f', min_f, max_f)
    min_f = 5
    max_f = 5.02
    if f is None:
        fs = np.random.random(n_samples) * (max_f - min_f) + min_f
    else:
        fs = np.repeat(f, n_samples)
        
    phases = np.random.random(n_samples) * 2*np.pi
    timesteps = np.arange(n_t) * dt
    x_train = []
    y_train = []    
    for i, phase in enumerate(phases):
        # x: beginning of cycle
        f = fs[i]
        d_phase = n_t * dt * f
        x_train.append(sin_(n_t, f, phase))
        # y: continuation of cycle        
        y_train.append(sin_(n_t, f, phase + d_phase))
    
    x_train = np.stack(x_train)
    x_train = x_train.reshape(n_samples, n_t, 1) 
    y_train = np.stack(y_train)
    y_train = y_train.reshape(n_samples, n_t, 1)
    return x_train, y_train
    
def sin_(n, f, phase=0, dt=0.01):
    ts = np.arange(n) * dt
    return (np.sin(2*np.pi * f * ts + phase * 2 * np.pi) + 1) * 0.5

# %%
n = 200
f = None
# f = 3
dt = 0.01
x_train, y_train = gen_xy_sin_to_f(n, f=f, dt=dt)
x_test, y_test = gen_xy_sin_to_f(10, f=f, dt=dt)
print(x_train.shape, y_train.shape)
# Out:
# allowed min max f 1.0 50.0
# allowed min max f 1.0 50.0
# (200, 100, 1) (200, 100, 1)

# %%
n4 = x_train.shape[1]
plt.plot(np.arange(n4) / n4 * dt, x_train[0])

# %%
plt.plot(np.arange(n4) / n4 * dt, y_train[0])

# %%
full = np.concatenate([x_train[0],y_train[0]])
n5 = full.shape[0]
plt.plot(np.arange(n5) / n5 * dt, full)

# %%
n_samples = x_train[0]
input_shape = x_train.shape[1:] # shape of a single sample
output_shape = y_train.shape[1:] # shape of a single sample
# output_length = y_train.shape[1:][0]
hidden_layer_length = 10
input_shape
# Out:
# (100, 1)

# %%
output_shape
# Out:
# (100, 1)

# %%
def encoder(input_shape, output_shape):
#     input_layer = Input(shape=input_shape)
    # input shape = (None, None, 1)
    # thus: unfixed n samples, unfixed n timesteps, 1 float value
    input_layer = Input(shape=(None,1))
    x = input_layer
    
    hidden_size = 512
    xs = LSTM(hidden_size, return_state=True)(x)
    x = xs[0]
    
    w = np.prod(output_shape) # * 2
    print('w =',w)
    x = Dense(w, activation='sigmoid')(x)
    x = Dense(w, activation='relu')(x)
    
    x = Dense(np.prod(output_shape), activation='sigmoid')(x)
    x = Reshape(output_shape)(x)
    model = Model(inputs=input_layer, outputs=x)
    return model

encoder = encoder(input_shape, output_shape)
encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, None, 1)           0
# _________________________________________________________________
# lstm_1 (LSTM)                [(None, 512), (None, 512) 1052672
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 100, 1)            0
# =================================================================
# Total params: 1,124,172
# Trainable params: 1,124,172
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = ['accuracy','mse','binary_crossentropy'] # sparse_categorical_accuracy
loss = 'binary_crossentropy'# binary_crossentropy categorical_crossentropy sparse_categorical_crossentropy
optimizer = 'adadelta'
encoder.compile(optimizer=optimizer, loss=loss, metrics=['mse', 'mae'])#, metrics=metrics)

# %%
batch_size = 64
# n epochs = n iterations over all the training data
epochs = 30

# %% [markdown]
# _Training with 50+ epochs results in better results, with a 'real' sine wave as ouput_

# %%
# decoder.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, callbacks=[TensorBoard(log_dir=config.tmp_log_dir)])
encoder.fit(x_train, x_train, epochs=epochs, batch_size=batch_size,
          validation_split=1/6, callbacks=[TensorBoard(log_dir=config.tmp_log_dir)])
# Out:
# Train on 166 samples, validate on 34 samples
# Epoch 1/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6927 - mean_squared_error: 0.1246 - mean_absolute_error: 0.3176 - val_loss: 0.6893 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3156
# Epoch 2/30
# 166/166 [==============================] - 3s 18ms/step - loss: 0.6926 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3176 - val_loss: 0.6892 - val_mean_squared_error: 0.1229 - val_mean_absolute_error: 0.3155
# Epoch 3/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6927 - mean_squared_error: 0.1246 - mean_absolute_error: 0.3176 - val_loss: 0.6894 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 4/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6926 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6894 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 5/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6926 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6895 - val_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.3158
# Epoch 6/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3176 - val_loss: 0.6894 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 7/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6893 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3156
# Epoch 8/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6926 - mean_squared_error: 0.1246 - mean_absolute_error: 0.3176 - val_loss: 0.6893 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 9/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6926 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3176 - val_loss: 0.6896 - val_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.3158
# Epoch 10/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6895 - val_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.3158
# Epoch 11/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6926 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3176 - val_loss: 0.6896 - val_mean_squared_error: 0.1231 - val_mean_absolute_error: 0.3158
# Epoch 12/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6894 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 13/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6894 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 14/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6895 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3157
# Epoch 15/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6893 - val_mean_squared_error: 0.1230 - val_mean_absolute_error: 0.3156
# Epoch 16/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6892 - val_mean_squared_error: 0.1229 - val_mean_absolute_error: 0.3156
# Epoch 17/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6891 - val_mean_squared_error: 0.1229 - val_mean_absolute_error: 0.3155
# Epoch 18/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6924 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6890 - val_mean_squared_error: 0.1228 - val_mean_absolute_error: 0.3154
# Epoch 19/30
# 166/166 [==============================] - 3s 18ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6890 - val_mean_squared_error: 0.1228 - val_mean_absolute_error: 0.3154
# Epoch 20/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6924 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3174 - val_loss: 0.6888 - val_mean_squared_error: 0.1227 - val_mean_absolute_error: 0.3153
# Epoch 21/30
# 166/166 [==============================] - 3s 18ms/step - loss: 0.6924 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3174 - val_loss: 0.6889 - val_mean_squared_error: 0.1228 - val_mean_absolute_error: 0.3154
# Epoch 22/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6888 - val_mean_squared_error: 0.1227 - val_mean_absolute_error: 0.3153
# Epoch 23/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6924 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3174 - val_loss: 0.6888 - val_mean_squared_error: 0.1227 - val_mean_absolute_error: 0.3153
# Epoch 24/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6885 - val_mean_squared_error: 0.1226 - val_mean_absolute_error: 0.3151
# Epoch 25/30
# 166/166 [==============================] - 3s 18ms/step - loss: 0.6924 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3174 - val_loss: 0.6883 - val_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.3150
# Epoch 26/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6925 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3175 - val_loss: 0.6883 - val_mean_squared_error: 0.1225 - val_mean_absolute_error: 0.3150
# Epoch 27/30
# 166/166 [==============================] - 3s 16ms/step - loss: 0.6923 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3174 - val_loss: 0.6882 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.3149
# Epoch 28/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6923 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3173 - val_loss: 0.6882 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.3149
# Epoch 29/30
# 166/166 [==============================] - 3s 18ms/step - loss: 0.6924 - mean_squared_error: 0.1245 - mean_absolute_error: 0.3174 - val_loss: 0.6882 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.3149
# Epoch 30/30
# 166/166 [==============================] - 3s 17ms/step - loss: 0.6923 - mean_squared_error: 0.1244 - mean_absolute_error: 0.3173 - val_loss: 0.6881 - val_mean_squared_error: 0.1224 - val_mean_absolute_error: 0.3148

# %%
x_test.shape
# Out:
# (10, 100, 1)

# %%
# x_test, y_test = gen_xy_sin_to_f(3, f=2)

# %%
results = encoder.predict(x_test)
results.shape
# Out:
# (10, 100, 1)

# %%
i = 0
selection = int(x_test.shape[1] * 1)
full = np.concatenate([x_test[i,-selection:],y_test[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)

# %%
i = 0
full = np.concatenate([x_test[i,-selection:],results[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)

# %%
i = 2
selection = int(x_test.shape[1] * 1)
full = np.concatenate([x_test[i,-selection:],results[i]])
n3 = full.shape[0]
plt.plot(np.arange(n3) / n3 * dt, full)
